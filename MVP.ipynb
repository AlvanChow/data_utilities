# %% [markdown]
# ## Import necessary packages

# %%
from pipeline import Outline_boxes
# %matplotlib inline
import matplotlib.pyplot as plt


from aug_util import draw_bboxes
from PIL import Image, ImageDraw
import pandas as pd

# %% [markdown]
# ## MVP

# %%
image = Outline_boxes(2120)
# Out:
# 100%|██████████| 601937/601937 [00:12<00:00, 48526.43it/s]
# Num Chips: 30

# %%
image.load_image()

# %%
# image.plot_all_chips_and_label()

# %%
image.coords
# Out:
# array([], shape=(0, 4), dtype=float64)

# %%
#0th Clip

# %%
image.labels[11]
# Out:
# 'Fixed-wing Aircraft'

# %%
image.c_cls[0]
# Out:
# array([0])

# %%
image.c_box[0]
# Out:
# array([[0, 0, 0, 0]])

# %%
image.load_image()

# %%
#Test image 2619

# %%
plt.imshow(image.arr)

# %%
img = image.arr

# %%
source1 = Image.fromarray(image.arr)

# %%
draw = ImageDraw.Draw(source1)

# %% [markdown]
# ## Classify Everything

# %%
df = pd.read_csv('../../baseline-1.1/inference/anothaone.csv', header=None)
df.head()
# Out:
#      0    1    2    3   4         5
# 0  173  182  300  257  73  0.961261
# 1  155  248  224  294  73  0.723187
# 2  284    2  299   22  35  0.530687
# 3  208    0  246   15  35  0.522139
# 4  237  260  295  295  73  0.460056

# %%
df = df.drop([5], axis = 1)
df.head(5)
# Out:
#      0    1    2    3   4
# 0  173  182  300  257  73
# 1  155  248  224  294  73
# 2  284    2  299   22  35
# 3  208    0  246   15  35
# 4  237  260  295  295  73

# %%
#Change into array
boxes = df.values

#Draw boxes onto image
draw_bboxes(img, boxes, image.labels)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# ## Think about it, try again

# %%
df = pd.read_csv('../../baseline-1.1/inference/anothaone.csv', header=None)
df.head()
# Out:
#      0    1    2    3   4         5
# 0  173  182  300  257  73  0.961261
# 1  155  248  224  294  73  0.723187
# 2  284    2  299   22  35  0.530687
# 3  208    0  246   15  35  0.522139
# 4  237  260  295  295  73  0.460056

# %%
df = df[df[5]>=0.5]
df.head()
# Out:
#        0    1    2    3   4         5
# 0    173  182  300  257  73  0.961261
# 1    155  248  224  294  73  0.723187
# 2    284    2  299   22  35  0.530687
# 3    208    0  246   15  35  0.522139
# 250  432  142  538  219  73  0.961781

# %%
df = df.drop([5], axis = 1)
df.head(5)
# Out:
#        0    1    2    3   4
# 0    173  182  300  257  73
# 1    155  248  224  294  73
# 2    284    2  299   22  35
# 3    208    0  246   15  35
# 250  432  142  538  219  73

# %%
#Change into array
boxes = df.values

#Draw boxes onto image
draw_bboxes(img, boxes, image.labels)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
