# %%
# %run -i 'process_wv.py' '../../train_images/' '../../xView_train.geojson' -s 'train_1'
# Out:
# 100%|██████████| 601937/601937 [00:03<00:00, 194924.62it/s]
# INFO:root:Res: (300, 300)
# 100%|██████████| 845/845 [14:09<00:00,  1.01s/it]
# INFO:root:Max chips per resolution: 51339
# INFO:root:Tot Box: 680805
# INFO:root:Chips: 34226
# INFO:root:saved: 23118 train chips
# INFO:root:saved: 11108 test chips

# %%
# !pwd ..
# Out:
# /Users/alvanchow/galvanize/xView_Capstone/train_images/data_utilities

# %%
with open('xview_class_labels.txt') as f:
    for line in f:
        print('item {')
        print('   id: ' + line[0:2])
        print("   name: '" + line[3:-1] + "'")
        print('}')
# Out:
# item {
#    id: 11
#    name: 'Fixed-wing Aircraft'
# }
# item {
#    id: 12
#    name: 'Small Aircraft'
# }
# item {
#    id: 13
#    name: 'Cargo Plane'
# }
# item {
#    id: 15
#    name: 'Helicopter'
# }
# item {
#    id: 17
#    name: 'Passenger Vehicle'
# }
# item {
#    id: 18
#    name: 'Small Car'
# }
# item {
#    id: 19
#    name: 'Bus'
# }
# item {
#    id: 20
#    name: 'Pickup Truck'
# }
# item {
#    id: 21
#    name: 'Utility Truck'
# }
# item {
#    id: 23
#    name: 'Truck'
# }
# item {
#    id: 24
#    name: 'Cargo Truck'
# }
# item {
#    id: 25
#    name: 'Truck w/Box'
# }
# item {
#    id: 26
#    name: 'Truck Tractor'
# }
# item {
#    id: 27
#    name: 'Trailer'
# }
# item {
#    id: 28
#    name: 'Truck w/Flatbed'
# }
# item {
#    id: 29
#    name: 'Truck w/Liquid'
# }
# item {
#    id: 32
#    name: 'Crane Truck'
# }
# item {
#    id: 33
#    name: 'Railway Vehicle'
# }
# item {
#    id: 34
#    name: 'Passenger Car'
# }
# item {
#    id: 35
# ...
